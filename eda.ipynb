# %%
import json
import os
import glob
from PIL import Image

# ===== 경로 설정 =====
label_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent\labels"
image_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent"

# ===== 이미지 정보 함수 =====
def get_image_info(img_path):
    try:
        with Image.open(img_path) as img:
            width, height = img.size
            mode = img.mode
        file_size_kb = os.path.getsize(img_path) / 1024
        return width, height, mode, file_size_kb
    except:
        return None, None, None, None

# ===== 1. JSON 여러 개 읽기 =====
all_entries = []

for json_file in glob.glob(os.path.join(label_folder, "*.json")):
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    if isinstance(data, dict):
        for fname, info in data.items():
            entry = {"file_name": fname}
            if isinstance(info, dict):
                entry.update(info)
            all_entries.append(entry)

    elif isinstance(data, list):
        for item in data:
            # file_name 없으면 건너뛰기
            if "file_name" not in item:
                print(f"⚠️ file_name 없어서 건너뜀: {item}")
                continue
            all_entries.append(item)

print(f"📌 전체 라벨 수: {len(all_entries)}")

# ===== 2. 이미지 전체 경로 매핑 =====
image_paths = glob.glob(os.path.join(image_folder, "**", "*.jpg"), recursive=True)
image_paths += glob.glob(os.path.join(image_folder, "**", "*.png"), recursive=True)
image_map = {os.path.basename(p): p for p in image_paths}

print(f"📌 전체 이미지 수: {len(image_map)}")

# ===== 3. 샘플 5개 이미지 정보 출력 =====
print("\n📌 이미지 기본 정보 (샘플 5개):")
count = 0
for entry in all_entries:
    if "file_name" not in entry:
        continue
    img_name = os.path.basename(entry["file_name"])
    if img_name in image_map:
        img_path = image_map[img_name]
        w, h, mode, size_kb = get_image_info(img_path)
        print(f"{img_name} → {w}x{h}px, 모드:{mode}, 크기:{size_kb:.1f}KB, 라벨:{entry.get('emotion')}")
    else:
        print(f"{img_name} → ❌ 이미지 없음")
    count += 1
    if count >= 5:
        break
# Out:
# ⚠️ file_name 없어서 건너뜀: {'filename': '5a30dc193e2c6144184968043c00773270b111a23a3c83b00f3971c9cc8a670d_남_30_기쁨_도심 환경_20201205004857-008-002.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 1905.6854, 'maxY': 1463.4427, 'minX': 1110.94, 'minY': 440.67734}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 1933.95158397587, 'maxY': 1513.78521741175, 'minX': 1013.45109777892, 'minY': 571.844123447761}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 1884.30234826051, 'maxY': 1506.37633552483, 'minX': 1122.77513130549, 'minY': 459.83909354858}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '0d18ae1ed7d9e912864b736523a94a24db0595bf273964cb532e62a6087cf325_여_30_기쁨_행사&사무공간_20201207000342-006-001.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '행사/사무공간', 'annot_A': {'boxes': {'maxX': 1851.23903563087, 'maxY': 1499.8602989002, 'minX': 1157.44878542176, 'minY': 474.33437846822}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 1859.27681006189, 'maxY': 1531.67307068141, 'minX': 1142.88031095972, 'minY': 442.255822383421}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 1857.54352722072, 'maxY': 1538.23303774334, 'minX': 1131.81797804244, 'minY': 419.856376467185}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '8f7e2f5214659c45cdcbc99a4e9ec29cf0b7571844a28e5f0de93af85aa7d76a_여_20_기쁨_문화재 및 유적지_20210129175103-009-002.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '문화재 및 유적지', 'annot_A': {'boxes': {'maxX': 1440.82398925781, 'maxY': 1333.728, 'minX': 781.879989257812, 'minY': 399.168}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1435.6430801085, 'maxY': 1328.45476988869, 'minX': 779.540120108499, 'minY': 410.83185896158}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1433.2561, 'maxY': 1309.4056, 'minX': 777.15314, 'minY': 413.16318}, 'faceExp': '기쁨', 'bg': '문화재 및 유적지'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '2964f04ec5e9bcc45276def3a6e08a3c2d1418995cf31f31d7fb9c147784c08a_남_50_기쁨_공공시설&종교&의료시설_20210125171959-001-013.jpg', 'gender': '남', 'age': 50, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 1466.7095, 'maxY': 1235.54712471507, 'minX': 727.559599999999, 'minY': 268.134088780826}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 1466.7095, 'maxY': 1243.42782627875, 'minX': 727.5596, 'minY': 223.57121607383}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 1466.7095, 'maxY': 1211.0664, 'minX': 727.5596, 'minY': 223.4748}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5feb258aabe4308f740ab36c133ef854074b138dcad3d6c66e519820dd2ec9b9_남_20_기쁨_스포츠 관람 및 레저시설_20210119120442-004-001.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '스포츠 관람 및 레저시설', 'annot_A': {'boxes': {'maxX': 951.6089, 'maxY': 1212.1552, 'minX': 126.75785, 'minY': 241.7569}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1048.76759788131, 'maxY': 1265.20865744374, 'minX': 57.5197051413153, 'minY': 294.810357443738}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 999.230403976603, 'maxY': 1242.96115027235, 'minX': 140.548110729278, 'minY': 303.068596786479}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '6c95a9432ec1dc577c3d2041ead6a86d920ab836420f02ab3981b4b1f73a6d35_남_20_기쁨_상업시설&점포&시장_20201207162128-003-021.jpg', 'gender': '남', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 1417.9183, 'maxY': 1465.1627, 'minX': 595.25354, 'minY': 359.65356}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 1431.92939465879, 'maxY': 1499.93208220522, 'minX': 636.821392709634, 'minY': 404.778914636884}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 1440.77539738189, 'maxY': 1503.10166200692, 'minX': 640.67230468707, 'minY': 401.369770406875}, 'faceExp': '중립', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '6a44de2e514d08e712dffc46e8133298af75b80668546e781bcee97fa777ca0e_남_20_기쁨_상업시설&점포&시장_20201205170307-003-009.jpg', 'gender': '남', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 962.957809918143, 'maxY': 1488.81001187503, 'minX': 469.660915871331, 'minY': 794.184146019704}, 'faceExp': '기쁨', 'bg': '행사/사무공간'}, 'annot_B': {'boxes': {'maxX': 993.582929787349, 'maxY': 1516.23556010033, 'minX': 432.440800932677, 'minY': 794.862160100328}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 987.03345, 'maxY': 1467.1522, 'minX': 459.05896, 'minY': 745.7788}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '26fb7dc0cd75beefc6b3c22583094b9441833566d0e30079d8dcea266a281950_남_20_기쁨_숙박 및 거주공간_20210204211729-010-007.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 2247.154, 'maxY': 1424.8005, 'minX': 1380.9102, 'minY': 364.37958}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 2208.08808396175, 'maxY': 1418.11040337747, 'minX': 1409.20538433093, 'minY': 453.64501246475}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 2247.154, 'maxY': 1424.8005, 'minX': 1380.9102, 'minY': 364.37958}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '559fa2f1d759bf4567906aba12d64a29b730535f6ea0a0e3d52d5baf025d7728_여_30_기쁨_교통&이동수단(엘리베이터 포함)_20201206005320-002-002.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 1313.2447292323, 'maxY': 1272.4901831118, 'minX': 698.474790492175, 'minY': 390.177053111803}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 1346.3864850898, 'maxY': 1272.46136192127, 'minX': 660.456330312236, 'minY': 390.148231921271}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 1315.75213736225, 'maxY': 1267.89149599454, 'minX': 689.495186785971, 'minY': 385.578365994539}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '1eab9325767c0fdbe195bcd9da5542f92609fcc1ebbb52953be96718dc57d82a_여_30_기쁨_오락&공연시설_20201206221022-005-004.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '오락/공연시설', 'annot_A': {'boxes': {'maxX': 1998.8778546875, 'maxY': 1603.8912, 'minX': 1098.0138546875, 'minY': 462.7968}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 1993.9122273772, 'maxY': 1568.17215408586, 'minX': 1100.9373695925, 'minY': 468.937016823232}, 'faceExp': '기쁨', 'bg': '오락/공연시설'}, 'annot_C': {'boxes': {'maxX': 1984.12713586205, 'maxY': 1603.79879275654, 'minX': 1108.92391654615, 'minY': 488.692152917505}, 'faceExp': '기쁨', 'bg': '오락/공연시설'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '36f3d025faf2e87a1c5e83c4b5c36964d2c80fb29a1d29739cb5ad1656386f99_남_20_기쁨_실외 자연환경_20210121103252-007-002.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 1615.0042, 'maxY': 1239.2245, 'minX': 951.11523, 'minY': 388.52618}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1639.80563348624, 'maxY': 1261.77128899083, 'minX': 975.916663486238, 'minY': 411.072968990826}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1645.30019678894, 'maxY': 1276.4029840006, 'minX': 974.71397005316, 'minY': 494.505590736236}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '821a4cf4393217eb1e67aa65c0daa2347025405a001df78d3caf90ea759adfab_여_30_기쁨_실외 자연환경_20210122144349-007-002.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 1866.19747886997, 'maxY': 1587.6154, 'minX': 1108.23423725906, 'minY': 482.21817}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1844.2421, 'maxY': 1587.6154, 'minX': 1108.1251, 'minY': 482.21817}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1844.2421, 'maxY': 1587.6154, 'minX': 1108.1251, 'minY': 482.21817}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5f2ac0f161ab6f0b07a219002d00c27397b1f15f0d470339aa0c8cf95eced4b0_남_20_기쁨_숙박 및 거주공간_20210119121700-010-008.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 2413.092, 'maxY': 1618.5979, 'minX': 1605.9414, 'minY': 581.94946}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 2468.58109369128, 'maxY': 1623.92448873336, 'minX': 1537.14302714768, 'minY': 587.276048733358}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_C': {'boxes': {'maxX': 2413.092, 'maxY': 1618.5979, 'minX': 1605.9414, 'minY': 581.94946}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '52e9bd799abddc270c5447644821c8fa11fc65cc1cdcaea54b24bc13ca69577c_여_30_기쁨_교통&이동수단(엘리베이터 포함)_20201201132438-002-003.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 2050.77479642641, 'maxY': 1749.52490192435, 'minX': 1052.93836056283, 'minY': 231.414244097153}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 2042.02008928571, 'maxY': 1754.57142857143, 'minX': 1051.37723214286, 'minY': 251.357142857143}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_C': {'boxes': {'maxX': 2043.70025884793, 'maxY': 1740.08153227803, 'minX': 1052.90073062575, 'minY': 310.281948774603}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '2e9ee57fed0d4333cb8cff62cab4b9dc05e90a73e108fa16ac0910e5c9de1d3d_여_20_기쁨_실외 자연환경_20210121172929-007-012.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 2609.012758884, 'maxY': 1353.54702841827, 'minX': 1880.88269391889, 'minY': 466.617782464886}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 2608.53526220615, 'maxY': 1385.04660715733, 'minX': 1862.06148282098, 'minY': 413.062988135592}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 2612.39379272792, 'maxY': 1381.01480882231, 'minX': 1863.61377580734, 'minY': 407.907671449429}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '75c554e12ca755112a797b612dc18fdff8fc1fb8c2c1dd636f6b312fa4768b10_여_30_기쁨_실외 자연환경_20201204220354-007-009.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 2438.0527, 'maxY': 1955.2617, 'minX': 1496.7048, 'minY': 697.2053}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 2420.83509646083, 'maxY': 1955.2617, 'minX': 1543.28162684014, 'minY': 697.2053}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 2438.24129465031, 'maxY': 2004.07574123475, 'minX': 1529.34284862142, 'minY': 659.321229712416}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '37a29bebaec2766329afbc04710e11ad7e47d5ea110a384574efd2f3f6a039fb_남_30_기쁨_행사&사무공간_20201205003024-006-003.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '행사/사무공간', 'annot_A': {'boxes': {'maxX': 2224.0002, 'maxY': 1739.8529, 'minX': 1349.6384, 'minY': 565.73096}, 'faceExp': '기쁨', 'bg': '오락/공연시설'}, 'annot_B': {'boxes': {'maxX': 2262.34974007884, 'maxY': 1787.65232918808, 'minX': 1387.98794007884, 'minY': 575.47728122468}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2238.42819608258, 'maxY': 1797.31671621613, 'minX': 1371.21040391742, 'minY': 580.267143783866}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '30ec2f1933c9645a6c418555299f14fb1d85f175d4a2ab87006652c07d7433f6_여_30_기쁨_숙박 및 거주공간_20210119203857-010-011.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1915.2903, 'maxY': 2377.8152, 'minX': 517.5231, 'minY': 268.1488}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1915.2903, 'maxY': 2377.8152, 'minX': 517.5231, 'minY': 268.1488}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1915.2903, 'maxY': 2377.8152, 'minX': 517.5231, 'minY': 268.1488}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '01a6c69e76d729863380b8391d780e53070cf8629ad9ffd5d06826551271fe74_남_30_기쁨_숙박 및 거주공간_20201207110157-010-006.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1195.50050655854, 'maxY': 1585.0187, 'minX': 476.561140998714, 'minY': 578.1605}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1208.12079660413, 'maxY': 1604.33212007772, 'minX': 442.394747289251, 'minY': 635.616062151686}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1195.2358, 'maxY': 1585.0187, 'minX': 407.29913, 'minY': 578.1605}, 'faceExp': '상처', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5a492f03b2d2b9401419999b80224fee64f211976fb3d82fd1ce32efab97a82c_여_30_기쁨_숙박 및 거주공간_20210210114352-010-005.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1623.59131592148, 'maxY': 1509.75431659506, 'minX': 739.407595195738, 'minY': 345.530028452865}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1615.26578947368, 'maxY': 1531.07368421053, 'minX': 737.876315789474, 'minY': 351.536842105263}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': -356.865355521936, 'maxY': -167.019667170953, 'minX': -356.865355521936, 'minY': -167.019667170953}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5d16991295ebfb1d04486e57f9f69a2cd616346f4a7c18e69a4bdc915c3e11f5_여_20_기쁨_숙박 및 거주공간_20210128115324-010-024.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1036.7875, 'maxY': 808.4324, 'minX': 601.53076, 'minY': 223.29358}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1036.7875, 'maxY': 808.4324, 'minX': 601.53076, 'minY': 223.29358}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1036.7875, 'maxY': 808.299708765933, 'minX': 601.530759999999, 'minY': 179.228946602589}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '9ac0965787c4f5e86edc5b38bb599954bc3d8a63202fb50a21d01b29e7861fb3_남_20_기쁨_오락&공연시설_20210130112557-005-003.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '오락/공연시설', 'annot_A': {'boxes': {'maxX': 2394.39198925781, 'maxY': 1526.976, 'minX': 1513.68798925781, 'minY': 586.08}, 'faceExp': '기쁨', 'bg': '오락/공연시설'}, 'annot_B': {'boxes': {'maxX': 2382.769, 'maxY': 1510.3994, 'minX': 1536.1407, 'minY': 445.32745}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 2382.7355394708, 'maxY': 1524.76533349029, 'minX': 1524.23925998671, 'minY': 476.338534817595}, 'faceExp': '기쁨', 'bg': '오락/공연시설'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4822f8249f35ae804e672696796f195f48e8111e8e62f34c88ad6d88dac48bf8_여_40_기쁨_공공시설&종교&의료시설_20201203125349-001-010.jpg', 'gender': '여', 'age': 40, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 2066.2148, 'maxY': 1621.009, 'minX': 1110.3892, 'minY': 303.56027}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 2066.2148, 'maxY': 1621.02366215372, 'minX': 1110.3892, 'minY': 307.955363943842}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2066.2148, 'maxY': 1621.009, 'minX': 1110.3892, 'minY': 303.56027}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '2e9aebef959a60bd3d75235f2325a7c7078cba209661ef4c8a104fac9d85f475_여_40_기쁨_상업시설&점포&시장_20210127181510-003-009.jpg', 'gender': '여', 'age': 40, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 1411.2922, 'maxY': 996.4077, 'minX': 1075.489, 'minY': 486.50958}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 1411.2922, 'maxY': 996.4077, 'minX': 1075.489, 'minY': 486.50958}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 1411.2922, 'maxY': 996.4077, 'minX': 1075.489, 'minY': 486.50958}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4c336a96ff37375f77cf1ba4a3f791e286b8bf10f2d125cb898c2f6e026f13c8_남_30_기쁨_숙박 및 거주공간_20201205000027-010-005.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1999.3632, 'maxY': 1594.3258, 'minX': 1049.1294, 'minY': 350.39117}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1965.14018463232, 'maxY': 1594.36247800681, 'minX': 1055.73520826066, 'minY': 357.258527985656}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1966.0299520331, 'maxY': 1585.93989880905, 'minX': 1074.08651776798, 'minY': 342.005268809052}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '9ac0965787c4f5e86edc5b38bb599954bc3d8a63202fb50a21d01b29e7861fb3_남_20_기쁨_상업시설&점포&시장_20210130112519-003-006.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 2329.32528115799, 'maxY': 1348.8595, 'minX': 1512.67433819685, 'minY': 371.54608}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 2318.93491255886, 'maxY': 1356.26233581505, 'minX': 1516.35311255886, 'minY': 476.392417084908}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 2325.98339933886, 'maxY': 1348.8595, 'minX': 1494.99698129519, 'minY': 371.54608}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5f656a0f627a3ef96dec882437e3e7ada1c7a877201cf54dcd7a2c4508588ff3_여_30_기쁨_문화재 및 유적지_20201204105851-009-005.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '문화재 및 유적지', 'annot_A': {'boxes': {'maxX': 1837.0157, 'maxY': 1441.1609, 'minX': 1129.0079, 'minY': 462.12146}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 1837.20420631807, 'maxY': 1441.22930544781, 'minX': 1157.3068088683, 'minY': 476.295544223795}, 'faceExp': '기쁨', 'bg': '문화재 및 유적지'}, 'annot_C': {'boxes': {'maxX': 1837.13394512912, 'maxY': 1441.22089277061, 'minX': 1157.94228644982, 'minY': 482.398309334651}, 'faceExp': '기쁨', 'bg': '문화재 및 유적지'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_남_30_기쁨_상업시설&점포&시장_20201206184354-003-004.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 2183.02, 'maxY': 1317.16288420632, 'minX': 1480.0493, 'minY': 305.339406899678}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 2175.65373883929, 'maxY': 1315.52678571429, 'minX': 1483.05552455357, 'minY': 295.071428571429}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 2182.99542737371, 'maxY': 1316.84311149399, 'minX': 1474.17152181255, 'minY': 299.453384967968}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '7d86799de902045bc68fe30deaa7ec520ff4d4ad44b6ac9bfe1a088a7428e50d_여_20_기쁨_숙박 및 거주공간_20210129145253-010-016.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1012.56683, 'maxY': 838.84863, 'minX': 517.051, 'minY': 157.90263}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1005.35032209617, 'maxY': 824.441569172947, 'minX': 515.587543233581, 'minY': 175.204576008225}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1012.56683, 'maxY': 838.84863, 'minX': 517.051, 'minY': 157.90263}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '0b33836b914f544c31e3a642ccccbb94114040537440b4df3b9250d025fc39a5_여_20_기쁨_숙박 및 거주공간_20210209150051-010-024.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 2655.51216651232, 'maxY': 1218.94158718887, 'minX': 1817.63484047969, 'minY': 162.050018742675}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 2655.11392405063, 'maxY': 1224.66780752131, 'minX': 1816.6329113924, 'minY': 138.476113264517}, 'faceExp': '불안', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 2667.38475536859, 'maxY': 1226.28815095273, 'minX': 1842.14463188292, 'minY': 198.67853136606}, 'faceExp': '분노', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '0ebaf6bd7d220a448bf362409d38d6fcd7c2de1e84a960cd75121893d7134894_남_30_기쁨_공공시설&종교&의료시설_20210118013248-001-015.jpg', 'gender': '남', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 2434.3462, 'maxY': 1706.507, 'minX': 1535.3223, 'minY': 553.78326}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 2434.3462, 'maxY': 1706.507, 'minX': 1535.3223, 'minY': 553.78326}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2467.139845628, 'maxY': 1776.08391608392, 'minX': 1568.39858688675, 'minY': 569.202797202797}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5087ab5d07d20f091502658130d22feb5137030a5dd3461947daae8c3be1db1a_남_40_기쁨_실외 자연환경_20201204233307-007-005.jpg', 'gender': '남', 'age': 40, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 1596.54738073395, 'maxY': 1658.71628807339, 'minX': 789.037280733945, 'minY': 528.212708073395}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1592.2905, 'maxY': 1633.09545688442, 'minX': 784.7804, 'minY': 481.4665667853}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1592.2905, 'maxY': 1667.59901079348, 'minX': 784.7804, 'minY': 481.524266008411}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '611fa5badcfbd0d4c538fd0a1f22bf3226456a71f645272266ba8ccbaa1b5ce8_남_40_기쁨_숙박 및 거주공간_20201206235621-010-007.jpg', 'gender': '남', 'age': 40, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 2002.54471556886, 'maxY': 1498.95271127965, 'minX': 1268.80701556886, 'minY': 466.564035426938}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1988.6525, 'maxY': 1477.35244687001, 'minX': 1254.9148, 'minY': 439.583617137523}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1988.6525, 'maxY': 1422.961, 'minX': 1254.9148, 'minY': 500.8791}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '0f22a4186f162f6151d71b7e6f2ed5d154765877a1300c5162d63b9c973da08f_남_20_기쁨_숙박 및 거주공간_20210209182330-010-015.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1494.09140625, 'maxY': 1958.95, 'minX': 538.74140625, 'minY': 699.625}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1482.46597339223, 'maxY': 1958.25814569806, 'minX': 541.549556243816, 'minY': 661.105937664152}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1482.4323, 'maxY': 1922.2476, 'minX': 533.5555, 'minY': 660.9917}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '44bdf93a45565ca88f5c19bdb8643684699f2252b295d7cd582c66bb1865a576_여_20_기쁨_실외 자연환경_20201206142501-007-002.jpg', 'gender': '여', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 1324.2664, 'maxY': 791.10913, 'minX': 831.7667, 'minY': 160.10477}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 1320.45483327873, 'maxY': 811.961924656989, 'minX': 831.751950931791, 'minY': 116.294080606169}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1324.2664, 'maxY': 791.10913, 'minX': 831.7667, 'minY': 160.10477}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '577a4a275693dd56ba4ccf986abf81109e45c09049f9dae500e30984ad417019_여_30_기쁨_문화재 및 유적지_20201207173353-009-012.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '문화재 및 유적지', 'annot_A': {'boxes': {'maxX': 2427.8403, 'maxY': 1666.2549, 'minX': 1479.8773, 'minY': 355.38287}, 'faceExp': '기쁨', 'bg': '문화재 및 유적지'}, 'annot_B': {'boxes': {'maxX': 2427.8403, 'maxY': 1666.2549, 'minX': 1479.8773, 'minY': 355.38287}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2427.8403, 'maxY': 1666.2549, 'minX': 1479.8773, 'minY': 355.38287}, 'faceExp': '기쁨', 'bg': '문화재 및 유적지'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4551a4c165093932b583c335b2c33abf357677f74c736c5e0ee8eb3b6c1306df_남_20_기쁨_도심 환경_20210203070310-008-004.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 2661.4844, 'maxY': 1789.8809, 'minX': 1789.8839, 'minY': 648.6549}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 2643.56493507525, 'maxY': 1761.16917389616, 'minX': 1811.42000145278, 'minY': 688.214657566135}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 2661.4844, 'maxY': 1789.8809, 'minX': 1789.8839, 'minY': 648.6549}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '3f562885545e60de1d61dd809ef6392cf799739d50cf1a4b6282d7b01c7e3216_여_30_기쁨_행사&사무공간_20201202181637-006-008.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '행사/사무공간', 'annot_A': {'boxes': {'maxX': 2315.89487161938, 'maxY': 1446.03540929167, 'minX': 1524.14226168297, 'minY': 351.819705505496}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 2274.26368390261, 'maxY': 1446.2655, 'minX': 1539.29576757183, 'minY': 435.3581}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2274.1484, 'maxY': 1446.2655, 'minX': 1518.424, 'minY': 435.3581}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '95aca5d2f492a11f1a762f56eeb4e946f8a9483a672c02a40695653b7835c36f_남_40_기쁨_오락&공연시설_20210122190751-005-002.jpg', 'gender': '남', 'age': 40, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '오락/공연시설', 'annot_A': {'boxes': {'maxX': 2240.70814727343, 'maxY': 2023.04249182088, 'minX': 1392.50207709933, 'minY': 759.178163017831}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 2254.4560372843, 'maxY': 2013.8353855295, 'minX': 1401.21213694737, 'minY': 786.811659148123}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 2257.11, 'maxY': 1969.2368, 'minX': 1359.4694, 'minY': 775.5645}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '2a3884fb335989165828041395bcbd9fea25a70d93a84fcefb0ee3dfd0ac7e84_남_20_기쁨_교통&이동수단(엘리베이터 포함)_20201203124618-002-005.jpg', 'gender': '남', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 1758.8977, 'maxY': 1539.7698, 'minX': 807.112, 'minY': 332.0063}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 1779.24887719298, 'maxY': 1551.98062631579, 'minX': 827.463077192982, 'minY': 344.21696631579}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_C': {'boxes': {'maxX': 1779.9888335405, 'maxY': 1564.70944745131, 'minX': 828.207158809226, 'minY': 248.001303856319}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '961b92c8462e23caf4b7721aa9b82ecbb344624b21ac16c74640e9bae2eb54a3_여_20_기쁨_공공시설&종교&의료시설_20210129123456-001-007.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 2553.6033, 'maxY': 1393.5781, 'minX': 1761.901, 'minY': 330.0502}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 2578.70235795113, 'maxY': 1438.17268798008, 'minX': 1778.68259304344, 'minY': 335.739427522816}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2582.43709330789, 'maxY': 1446.37108885814, 'minX': 1771.66720669211, 'minY': 320.682211141862}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4822f8249f35ae804e672696796f195f48e8111e8e62f34c88ad6d88dac48bf8_여_40_기쁨_문화재 및 유적지_20201203125458-009-013.jpg', 'gender': '여', 'age': 40, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '문화재 및 유적지', 'annot_A': {'boxes': {'maxX': 2107.72, 'maxY': 1563.4554, 'minX': 1218.3513, 'minY': 305.61682}, 'faceExp': '기쁨', 'bg': '문화재 및 유적지'}, 'annot_B': {'boxes': {'maxX': 2107.72, 'maxY': 1563.4554, 'minX': 1218.3513, 'minY': 305.61682}, 'faceExp': '기쁨', 'bg': '문화재 및 유적지'}, 'annot_C': {'boxes': {'maxX': 2107.72, 'maxY': 1601.18215652909, 'minX': 1218.3513, 'minY': 305.703832703197}, 'faceExp': '기쁨', 'bg': '문화재 및 유적지'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '96fa4f5e8e4b5cdbd8a85de2b11bebbf0c1258d46da614df55c94de4c5e4b53c_여_30_기쁨_실외 자연환경_20210131193709-007-003.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 2477.3208, 'maxY': 1947.6035, 'minX': 1763.8792, 'minY': 907.28955}, 'faceExp': '당황', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 2477.3208, 'maxY': 1947.6035, 'minX': 1763.8792, 'minY': 907.28955}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 2477.3208, 'maxY': 1947.6035, 'minX': 1763.8792, 'minY': 907.28955}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '6a8bc64669cb59cf0b5a067178532f65a93745887223463ca7653aacee89840e_여_20_기쁨_도심 환경_20210203160036-008-017.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 2150.52220377389, 'maxY': 1213.55978014089, 'minX': 1396.98411959415, 'minY': 202.406610249616}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 2148.60886981173, 'maxY': 1229.97487630748, 'minX': 1408.75899995571, 'minY': 219.568812762291}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 2149.63359108587, 'maxY': 1213.27811948111, 'minX': 1401.41768631015, 'minY': 199.400569363314}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4497ca678f58f055a90de5a8bf2d9b318063fc66935f8f8b991c243332b89a04_여_30_기쁨_교통&이동수단(엘리베이터 포함)_20201207025122-002-010.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 1778.6963, 'maxY': 1331.9071, 'minX': 1015.0746, 'minY': 350.36322}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1776.03887180305, 'maxY': 1345.96661212768, 'minX': 1042.63428383605, 'minY': 444.21348230841}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1778.78281491978, 'maxY': 1350.56044688066, 'minX': 1036.69595024876, 'minY': 384.428974242939}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4333f84bcb60a497ddc6033eca43d12041e93c0df7d4774a585729cc30ab8340_여_30_기쁨_도심 환경_20210119113819-008-001.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 2251.0857, 'maxY': 1955.9746, 'minX': 1341.7985, 'minY': 722.2104}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 2259.46186590679, 'maxY': 1972.72832340329, 'minX': 1350.17466590679, 'minY': 738.964123403286}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 2251.0857, 'maxY': 1955.9746, 'minX': 1341.7985, 'minY': 722.2104}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '8fb6875bb0de4ce651aaf4c759f22e8c8265ff43c016507230e14ae686673b32_남_40_기쁨_공공시설&종교&의료시설_20201206180407-001-005.jpg', 'gender': '남', 'age': 40, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 1486.24439251078, 'maxY': 1657.8988351549, 'minX': 483.116062084741, 'minY': 561.623282401041}, 'faceExp': '기쁨', 'bg': '행사/사무공간'}, 'annot_B': {'boxes': {'maxX': 1508.9626, 'maxY': 1549.1781788531, 'minX': 483.19992, 'minY': 352.907111972587}, 'faceExp': '기쁨', 'bg': '행사/사무공간'}, 'annot_C': {'boxes': {'maxX': 1505.19605456629, 'maxY': 1740.32349972644, 'minX': 483.186089693443, 'minY': 538.151874847587}, 'faceExp': '기쁨', 'bg': '행사/사무공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '3b41262ea64af03434c6d5553470563bfd0ad8f26943fb644076a37e3a92161a_남_40_기쁨_문화재 및 유적지_20210126110944-009-001.jpg', 'gender': '남', 'age': 40, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '문화재 및 유적지', 'annot_A': {'boxes': {'maxX': 1909.3158, 'maxY': 1291.3796, 'minX': 1103.542, 'minY': 290.07495}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 1856.06962025316, 'maxY': 1337.65435369042, 'minX': 1091.32459312839, 'minY': 337.327214693732}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 1891.86914538879, 'maxY': 1303.01131091857, 'minX': 1086.09534538879, 'minY': 301.706660918566}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5ffd2c1dc31f3a8f6ed1d5c22ef3a81b52ca827b5fdda5fd1fc9d265baa927af_여_20_기쁨_숙박 및 거주공간_20210127172133-010-022.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 2548.5283, 'maxY': 1196.4734, 'minX': 1758.3892, 'minY': 150.38078}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 2557.91431823708, 'maxY': 1171.51627381388, 'minX': 1767.77521823708, 'minY': 147.187909679978}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 2548.5283, 'maxY': 1196.4734, 'minX': 1758.3892, 'minY': 150.38078}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4adfb1ab5c0b58584cdb28f928938353e18aece79fbe8594206e8cc9d4e2f0f5_남_30_기쁨_상업시설&점포&시장_20201202204217-003-001.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 1756.255, 'maxY': 1639.4857, 'minX': 1004.6152, 'minY': 676.21533}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 1795.47157833008, 'maxY': 1661.8414324084, 'minX': 1027.23357312623, 'minY': 676.345034484802}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 1780.63394736842, 'maxY': 1700.47138815931, 'minX': 1028.99414736842, 'minY': 749.313852367001}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '60f9f06dcbf85639b594a076906a68377135895dea575eb480365fc426c7b6a0_여_40_기쁨_교통&이동수단(엘리베이터 포함)_20201202191229-002-005.jpg', 'gender': '여', 'age': 40, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 1984.4072, 'maxY': 1628.85988934159, 'minX': 1167.54, 'minY': 450.159822593893}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 1990.725, 'maxY': 1652.4, 'minX': 1177.125, 'minY': 464.4}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_C': {'boxes': {'maxX': 1988.0227894809, 'maxY': 1643.34633129316, 'minX': 1174.7247105191, 'minY': 473.905818706834}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '9c967da4cea00ae0b1e9699b35df07f3cdfe5f808ba57e636a87fe9704b83f74_남_40_기쁨_공공시설&종교&의료시설_20210121191354-001-002.jpg', 'gender': '남', 'age': 40, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 1878.5824, 'maxY': 1527.1263, 'minX': 1063.2865, 'minY': 414.4156}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 1939.5719590098, 'maxY': 1529.78959436668, 'minX': 1052.87220180216, 'minY': 417.078894366679}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 1878.60801987334, 'maxY': 1521.86977252849, 'minX': 1071.24641358054, 'minY': 438.315061946969}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '611fa5badcfbd0d4c538fd0a1f22bf3226456a71f645272266ba8ccbaa1b5ce8_남_40_기쁨_상업시설&점포&시장_20201206235526-003-023.jpg', 'gender': '남', 'age': 40, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 2377.6868, 'maxY': 1691.1536, 'minX': 1591.5496, 'minY': 593.00507}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 2380.73943157895, 'maxY': 1691.22111027428, 'minX': 1594.60223157895, 'minY': 617.358612357296}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 2377.6868, 'maxY': 1691.1536, 'minX': 1591.5496, 'minY': 593.00507}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '75c554e12ca755112a797b612dc18fdff8fc1fb8c2c1dd636f6b312fa4768b10_여_30_기쁨_상업시설&점포&시장_20201204220328-003-017.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 2366.3623, 'maxY': 1849.0077, 'minX': 1406.8193, 'minY': 487.87646}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 2345.51195841835, 'maxY': 1885.37822856121, 'minX': 1406.70603672897, 'minY': 441.024129012448}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 2366.3623, 'maxY': 1849.0077, 'minX': 1406.8193, 'minY': 487.87646}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '9df04502c22931ea10324833f1a973bc2f28a98f62c2ae9b18df98c40d02aa29_여_40_기쁨_도심 환경_20210128163504-008-024.jpg', 'gender': '여', 'age': 40, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 1537.7998, 'maxY': 1471.2322, 'minX': 739.31854, 'minY': 375.78815}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1534.26759882701, 'maxY': 1460.61753319463, 'minX': 739.302915086037, 'minY': 375.753883148155}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1537.7998, 'maxY': 1471.2322, 'minX': 739.31854, 'minY': 375.78815}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '6e00acee12b8f9d23a161f2f4eadc6c8c69c73d6a1e1dcca29f77f7c0908cf6b_남_30_기쁨_공공시설&종교&의료시설_20201209152809-001-003.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 1833.67803179313, 'maxY': 1593.41838053684, 'minX': 1005.2369524174, 'minY': 530.543766831586}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 1835.74925058909, 'maxY': 1607.31970293696, 'minX': 1005.63629183515, 'minY': 503.687608455688}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 1835.55972186087, 'maxY': 1603.20246923449, 'minX': 1005.32615501636, 'minY': 506.438018975519}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '33baf31f61241358f6898cfa7e3262bf409725c44caf6f660e16dc33940fc305_여_20_기쁨_실외 자연환경_20210213231303-007-001.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 2857.4492, 'maxY': 1486.5435, 'minX': 2049.6943, 'minY': 467.0086}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 2857.4492, 'maxY': 1486.5435, 'minX': 2049.6943, 'minY': 467.0086}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 2857.4492, 'maxY': 1486.5435, 'minX': 2049.6943, 'minY': 467.0086}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '559fa2f1d759bf4567906aba12d64a29b730535f6ea0a0e3d52d5baf025d7728_여_30_기쁨_공공시설&종교&의료시설_20201206005315-001-011.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 2066.279, 'maxY': 1344.8654, 'minX': 1401.2595, 'minY': 468.01416}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 2066.31302645368, 'maxY': 1380.59236926298, 'minX': 1410.77339398031, 'minY': 468.111152559033}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2066.34457017435, 'maxY': 1383.34173686801, 'minX': 1416.02539049981, 'minY': 474.06119172256}, 'faceExp': '기쁨', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '8d08e1acf6ef589b06970e3d5ec78444fd26c9adf4382a272d321516dd742c42_여_30_기쁨_오락&공연시설_20201203155037-005-013.jpg', 'gender': '여', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '오락/공연시설', 'annot_A': {'boxes': {'maxX': 2410.8594, 'maxY': 1708.0977, 'minX': 1453.463, 'minY': 373.48682}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 2411.35818274966, 'maxY': 1664.29842539475, 'minX': 1519.02246967752, 'minY': 373.247259653793}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 2403.21833196514, 'maxY': 1684.3570605645, 'minX': 1516.66312315296, 'minY': 373.416435813453}, 'faceExp': '기쁨', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '85f982251ee05d8b8c215aa2bbfa65bb0e93f18192a16c772c57f07a42958720_남_20_기쁨_숙박 및 거주공간_20210218180939-010-005.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 777.3178778, 'maxY': 734.2547075, 'minX': 347.9786578, 'minY': 179.8274575}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 775.1728778, 'maxY': 734.7347075, 'minX': 353.7546578, 'minY': 181.8014575}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 775.7068778, 'maxY': 731.1237075, 'minX': 347.7926578, 'minY': 181.5274575}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '98f8eccc6365a07f4274f9f564df9217995dd3534b308c0299b8242768568d92_여_20_기쁨_상업시설&점포&시장_20210125173412-003-002.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 954.60315, 'maxY': 762.45795, 'minX': 537.79865, 'minY': 182.86877}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 929.01910867012, 'maxY': 760.326042592652, 'minX': 512.21460867012, 'minY': 180.736862592653}, 'faceExp': '중립', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 942.664896978374, 'maxY': 763.946930716254, 'minX': 518.468307980303, 'minY': 184.357750716253}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '44bdf93a45565ca88f5c19bdb8643684699f2252b295d7cd582c66bb1865a576_여_20_기쁨_스포츠 관람 및 레저시설_20201206142433-004-006.jpg', 'gender': '여', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '스포츠 관람 및 레저시설', 'annot_A': {'boxes': {'maxX': 1243.29528412671, 'maxY': 917.292673828074, 'minX': 738.660184316563, 'minY': 203.840379250463}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1245.33714301397, 'maxY': 923.337780800195, 'minX': 689.783403013975, 'minY': 203.825919943233}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1255.905, 'maxY': 891.6971, 'minX': 700.35126, 'minY': 203.74512}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '3ee617be69e68d69023cb585b5ca98b53ca0c141f657728dc117ac61a579e27b_여_20_기쁨_숙박 및 거주공간_20210119162118-010-027.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1541.2876, 'maxY': 1318.4336, 'minX': 789.43463, 'minY': 335.84634}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1541.2876, 'maxY': 1318.4336, 'minX': 789.43463, 'minY': 335.84634}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1557.93805128604, 'maxY': 1322.6186736466, 'minX': 776.987077264683, 'minY': 335.864164904121}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '96fa4f5e8e4b5cdbd8a85de2b11bebbf0c1258d46da614df55c94de4c5e4b53c_여_30_기쁨_실외 자연환경_20210131193709-007-006.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 2576.64187834406, 'maxY': 1823.76747019644, 'minX': 1826.96751592742, 'minY': 829.063511367928}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 2589.21840904441, 'maxY': 1848.73294513358, 'minX': 1812.11235617298, 'minY': 829.223224431629}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 2556.5906, 'maxY': 1788.8121, 'minX': 1811.8706, 'minY': 828.8832}, 'faceExp': '기쁨', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '6ea444752308b9fc4ce87b2dc63c1341da53b94bc7804a5ea3106732950ca1ac_여_20_기쁨_도심 환경_20201207141217-008-002.jpg', 'gender': '여', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 1869.60012530829, 'maxY': 1392.51524348298, 'minX': 1051.36392530829, 'minY': 389.563883482981}, 'faceExp': '기쁨', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 1856.33787651812, 'maxY': 1380.06906287712, 'minX': 1074.72996736718, 'minY': 299.111809943301}, 'faceExp': '기쁨', 'bg': '스포츠 관람 및 레저시설'}, 'annot_C': {'boxes': {'maxX': 1856.34373171921, 'maxY': 1371.29619242074, 'minX': 1079.65537122966, 'minY': 231.103941732474}, 'faceExp': '기쁨', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5b77f18724833ccd71967b89d9152a588ed584df00d93975a10da488cf670209_여_20_기쁨_숙박 및 거주공간_20210208164134-010-028.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 3027.89476106736, 'maxY': 1357.7417, 'minX': 2174.77903893264, 'minY': 322.6944}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 3028.372012431, 'maxY': 1368.45367826014, 'minX': 2189.053412431, 'minY': 319.156669014444}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 3040.97031556845, 'maxY': 1372.31316237515, 'minX': 2185.12539522119, 'minY': 357.943526562805}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '3a6bfd5a281e4b62b1135a59f81d7179286c47a44c164d3963eee29f48463c8c_남_30_기쁨_교통&이동수단(엘리베이터 포함)_20201203152009-002-018.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '기쁨', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 1641.5896, 'maxY': 1538.0594, 'minX': 837.7086, 'minY': 475.46817}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 1641.70609531599, 'maxY': 1538.01511575685, 'minX': 851.400608237522, 'minY': 468.608508250686}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_C': {'boxes': {'maxX': 1641.5895, 'maxY': 1538.0594, 'minX': 837.7086, 'minY': 475.46826}, 'faceExp': '기쁨', 'bg': '교통/이동수단(엘리베이터 포함)'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '7d316d614dbd22b33df44768199cffa8212ad676673c6bf02b50e1834f8cf2cb_여_20_기쁨_숙박 및 거주공간_20210210123523-010-016.jpg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '기쁨', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 1297.6562, 'maxY': 1169.3048, 'minX': 446.99188, 'minY': 0}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 1292.02072368421, 'maxY': 1173.05366695427, 'minX': 457.041776315789, 'minY': 0}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 1308.06000228798, 'maxY': 1181.41538860488, 'minX': 445.388861348383, 'minY': 0}, 'faceExp': '기쁨', 'bg': '숙박 및 거주공간'}}
# ...
# ⚠️ file_name 없어서 건너뜀: {'filename': '3fd10befe08024d2bac782beec621aad2a7f6f467ba2330a04c083826074003e_남_30_중립_공공시설&종교&의료시설_20201208145048-001-007.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 2612.16, 'maxY': 2169.126, 'minX': 1695.6953, 'minY': 1011.1043}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 2562.93663292406, 'maxY': 2218.53585476506, 'minX': 1714.00957616684, 'minY': 1045.14899068948}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2566.21153928509, 'maxY': 2204.66067338393, 'minX': 1720.31042738157, 'minY': 1032.49458962601}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '3fd10befe08024d2bac782beec621aad2a7f6f467ba2330a04c083826074003e_남_30_중립_교통&이동수단(엘리베이터 포함)_20201208145055-002-010.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 2232.5981, 'maxY': 2092.7842, 'minX': 1466.4166, 'minY': 1061.9784}, 'faceExp': '중립', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 2215.88673366201, 'maxY': 2126.64029864636, 'minX': 1483.12796633799, 'minY': 1084.65809812038}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2232.5981, 'maxY': 2092.7842, 'minX': 1466.4166, 'minY': 1061.9784}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '440d245048f7b149a1bb02d5bcc10ef42bfb1e99cc392bea0394d367d6cc78ca_여_20_중립_교통&이동수단(엘리베이터 포함)_20201204103826-002-005.jpg', 'gender': '여', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 2155.0093, 'maxY': 1591.2977, 'minX': 1259.4642, 'minY': 500.73535}, 'faceExp': '중립', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 2147.1901920841, 'maxY': 1596.45032880907, 'minX': 1307.21097518534, 'minY': 434.327365057293}, 'faceExp': '중립', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_C': {'boxes': {'maxX': 2155.0093, 'maxY': 1591.2977, 'minX': 1259.4642, 'minY': 500.73535}, 'faceExp': '중립', 'bg': '교통/이동수단(엘리베이터 포함)'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '1bf6a0788d749748046926895ec0d21a9bf47084dc62daa9974b1daa799008ed_여_50_중립_상업시설&점포&시장_20210126202106-003-022.jpg', 'gender': '여', 'age': 50, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 2808.86607565119, 'maxY': 1576.54437590771, 'minX': 1536.8381361867, 'minY': 253.3098746165}, 'faceExp': '중립', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 2727.9611482583, 'maxY': 1626.93772830612, 'minX': 1700.49054464216, 'minY': 369.499692907628}, 'faceExp': '중립', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 2760.7083, 'maxY': 1634.1455, 'minX': 1715.136, 'minY': 347.71204}, 'faceExp': '중립', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_남_30_중립_교통&이동수단(엘리베이터 포함)_20201206184602-002-011.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 2122.802, 'maxY': 1504.0878, 'minX': 1279.682, 'minY': 311.83875}, 'faceExp': '중립', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 2142.86802455357, 'maxY': 1524.53571428571, 'minX': 1323.22516741071, 'minY': 315.5625}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 2162.24963179799, 'maxY': 1521.94465659494, 'minX': 1308.4589876259, 'minY': 290.38703468053}, 'faceExp': '중립', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '5c2261c629f9f20130b1127d24231c162a7b62ff959abe417da7cf644f571da3_여_20_중립_숙박 및 거주공간_20210128041235-010-021.jpeg', 'gender': '여', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 2308.2812, 'maxY': 1896.74068930133, 'minX': 1314.9995, 'minY': 532.744407014462}, 'faceExp': '불안', 'bg': '숙박 및 거주공간'}, 'annot_B': {'boxes': {'maxX': 2317.34894707033, 'maxY': 1930.31260064172, 'minX': 1308.96972732235, 'minY': 511.634906785711}, 'faceExp': '당황', 'bg': '숙박 및 거주공간'}, 'annot_C': {'boxes': {'maxX': 2308.2812, 'maxY': 1936.418, 'minX': 1314.9995, 'minY': 532.85657}, 'faceExp': '중립', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '8a56e91b5272fbf93d0f5257b391ab6a7487d5a1416c9384d1c7516dc08a5068_남_30_중립_스포츠 관람 및 레저시설_20210208164741-004-008.jpg', 'gender': '남', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '스포츠 관람 및 레저시설', 'annot_A': {'boxes': {'maxX': 2427.64694727691, 'maxY': 1324.90513078968, 'minX': 1713.22658413851, 'minY': 311.503001572235}, 'faceExp': '중립', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 2427.69785426166, 'maxY': 1331.9813781219, 'minX': 1725.70125878182, 'minY': 310.05157090647}, 'faceExp': '중립', 'bg': '스포츠 관람 및 레저시설'}, 'annot_C': {'boxes': {'maxX': 2427.62499802425, 'maxY': 1339.54893208318, 'minX': 1715.66313145134, 'minY': 281.346005828321}, 'faceExp': '중립', 'bg': '스포츠 관람 및 레저시설'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4adfb1ab5c0b58584cdb28f928938353e18aece79fbe8594206e8cc9d4e2f0f5_남_30_중립_교통&이동수단(엘리베이터 포함)_20201202204440-002-018.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 1817.517, 'maxY': 1775.8838, 'minX': 1000.12836, 'minY': 753.13727}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 1798.40508136861, 'maxY': 1775.86058074824, 'minX': 1058.41152598869, 'minY': 748.264083332097}, 'faceExp': '중립', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1817.6584689897, 'maxY': 1775.8838, 'minX': 1037.37942380545, 'minY': 753.13727}, 'faceExp': '중립', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '9dbc66073c47d92f7d9f79f355985d3ac03d6ccf0dc3dc559b5b364623460577_남_40_중립_상업시설&점포&시장_20210126181808-003-009.jpg', 'gender': '남', 'age': 40, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 3176.801, 'maxY': 2389.0696, 'minX': 1849.4445, 'minY': 557.4845}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 3135.42588596215, 'maxY': 2378.64396545839, 'minX': 1870.01067549036, 'minY': 541.882802003437}, 'faceExp': '중립', 'bg': '스포츠 관람 및 레저시설'}, 'annot_C': {'boxes': {'maxX': 3176.801, 'maxY': 2389.0696, 'minX': 1849.4445, 'minY': 557.4845}, 'faceExp': '분노', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '088fed93316d43566be2fd844159eabf77e3025bf465076921ef38e9726bd8c1_남_20_중립_공공시설&종교&의료시설_20201209150503-001-031.jpg', 'gender': '남', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 5731.33379898934, 'maxY': 4338.292, 'minX': 3780.74388421677, 'minY': 1559.483}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 5764.29563176346, 'maxY': 4413.77794884896, 'minX': 3693.82001035091, 'minY': 1521.93119326543}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 5764.2974704936, 'maxY': 4438.83216981901, 'minX': 3706.28402950641, 'minY': 1559.74283018099}, 'faceExp': '중립', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '30ec2f1933c9645a6c418555299f14fb1d85f175d4a2ab87006652c07d7433f6_여_30_중립_행사&사무공간_20210119211311-006-004.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '행사/사무공간', 'annot_A': {'boxes': {'maxX': 2883.17692190712, 'maxY': 2233.51433319039, 'minX': 1555.67057672302, 'minY': 372.07243654276}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 2878.5654, 'maxY': 2225.071, 'minX': 1428.4684, 'minY': 389.0179}, 'faceExp': '당황', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 2878.85289638368, 'maxY': 2225.071, 'minX': 1512.65475633777, 'minY': 389.0179}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '38e8f51cc8c20a998ce151704b874340a527858189162eb3614ae62672bcfd0f_남_30_중립_스포츠 관람 및 레저시설_20201207012624-004-004.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '스포츠 관람 및 레저시설', 'annot_A': {'boxes': {'maxX': 2185.67939323351, 'maxY': 1537.00436979161, 'minX': 1455.51001087607, 'minY': 521.793941945313}, 'faceExp': '중립', 'bg': '스포츠 관람 및 레저시설'}, 'annot_B': {'boxes': {'maxX': 2185.70101645225, 'maxY': 1537.18348136104, 'minX': 1455.52754180018, 'minY': 563.469278736043}, 'faceExp': '중립', 'bg': '스포츠 관람 및 레저시설'}, 'annot_C': {'boxes': {'maxX': 2185.65095239647, 'maxY': 1536.8076, 'minX': 1442.17954760353, 'minY': 469.52283}, 'faceExp': '중립', 'bg': '스포츠 관람 및 레저시설'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '2aafb545c9a93c39542e483186fe25fe1cb3709a9b8d0209e06e2163db88954c_남_30_중립_상업시설&점포&시장_20201202144152-003-014.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '상업시설/점포/시장', 'annot_A': {'boxes': {'maxX': 2525.2856, 'maxY': 2332.5327, 'minX': 1472.8615, 'minY': 1036.3672}, 'faceExp': '중립', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 2542.37614678899, 'maxY': 2358.16513761468, 'minX': 1488.1376146789, 'minY': 971.009174311927}, 'faceExp': '슬픔', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 2542.22589274566, 'maxY': 2340.72981284419, 'minX': 1489.80356019551, 'minY': 960.405381273456}, 'faceExp': '슬픔', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '6e00acee12b8f9d23a161f2f4eadc6c8c69c73d6a1e1dcca29f77f7c0908cf6b_남_30_중립_실외 자연환경_20201209153052-007-007.jpg', 'gender': '남', 'age': 30, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 1787.3582, 'maxY': 1553.1403, 'minX': 905.10767, 'minY': 382.30792}, 'faceExp': '중립', 'bg': '실외 자연환경'}, 'annot_B': {'boxes': {'maxX': 1787.3582, 'maxY': 1553.1403, 'minX': 905.10767, 'minY': 382.30792}, 'faceExp': '당황', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 1787.400158682, 'maxY': 1553.1403, 'minX': 917.27623763379, 'minY': 382.30792}, 'faceExp': '불안', 'bg': '숙박 및 거주공간'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '0cebc58b878df61c71de8e92bf181af059fe272b432e0ff5bab15d4aa12504f6_여_20_중립_오락&공연시설_20201202162324-005-012.jpg', 'gender': '여', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '오락/공연시설', 'annot_A': {'boxes': {'maxX': 894.6108, 'maxY': 769.7527, 'minX': 461.7702, 'minY': 171.50462}, 'faceExp': '중립', 'bg': '오락/공연시설'}, 'annot_B': {'boxes': {'maxX': 876.930322182458, 'maxY': 763.195102383898, 'minX': 461.6799268294, 'minY': 193.611624730726}, 'faceExp': '중립', 'bg': '오락/공연시설'}, 'annot_C': {'boxes': {'maxX': 894.6108, 'maxY': 769.7527, 'minX': 461.7702, 'minY': 171.50462}, 'faceExp': '중립', 'bg': '오락/공연시설'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '0a88a23fd9e2225216ed0ab0e2c1d01801be2e23b1f916fcab139fccd47811d2_남_20_중립_도심 환경_20210125172145-008-001.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 1808.964128, 'maxY': 1798.666366, 'minX': 757.164928, 'minY': 495.222966}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 1818.776128, 'maxY': 1797.171366, 'minX': 757.860928, 'minY': 506.559966}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 1811.776128, 'maxY': 1803.203366, 'minX': 763.279928, 'minY': 495.633966}, 'faceExp': '중립', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '46c437c5362ab25921e683613306b7d61b3216c643725852b5fd5a7838e9ffba_여_30_중립_실외 자연환경_20210115221156-007-004.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '실외 자연환경', 'annot_A': {'boxes': {'maxX': 2393.04801478654, 'maxY': 2195.7083, 'minX': 1313.43291345773, 'minY': 601.970899999999}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 2391.1677631579, 'maxY': 2187.56842105263, 'minX': 1319.78881578947, 'minY': 651.789473684211}, 'faceExp': '중립', 'bg': '실외 자연환경'}, 'annot_C': {'boxes': {'maxX': 2411.80508917701, 'maxY': 2195.7083, 'minX': 1299.31175522, 'minY': 601.9709}, 'faceExp': '중립', 'bg': '실외 자연환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '83f5aca10297a150ce4fb846a99536180d7320a90951655a6f1310da41590e7a_여_30_중립_도심 환경_20210129132058-008-001.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 2834.3105, 'maxY': 1446.72619165218, 'minX': 1938.2428, 'minY': 289.216583747185}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 2838.77661298279, 'maxY': 1488.8633565465, 'minX': 1938.26505911023, 'minY': 289.353287639551}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 2834.34259250318, 'maxY': 1437.87184165066, 'minX': 1945.90186565374, 'minY': 319.835428176001}, 'faceExp': '중립', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '62a47ba6c1092e714871ab1bd42a28d425d60dc79d506ec535c3a11e43d6c8c3_남_20_중립_공공시설&종교&의료시설_20201206140050-001-005.jpg', 'gender': '남', 'age': 20, 'isProf': '전문인', 'faceExp_uploader': '중립', 'bg_uploader': '공공시설/종교/의료시설', 'annot_A': {'boxes': {'maxX': 1880.47091111842, 'maxY': 1616.5841, 'minX': 1041.94619727853, 'minY': 444.98392}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}, 'annot_B': {'boxes': {'maxX': 1863.7214732054, 'maxY': 1636.23130090366, 'minX': 1026.60736315823, 'minY': 520.124597884224}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}, 'annot_C': {'boxes': {'maxX': 1880.3169, 'maxY': 1616.5841, 'minX': 1001.6483, 'minY': 444.98392}, 'faceExp': '중립', 'bg': '공공시설/종교/의료'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '278a8a307724862bf7dd7a87bb6ef6a9c463981ce56878c8de826e067796c614_여_30_중립_도심 환경_20210216143335-008-016.jpg', 'gender': '여', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '도심 환경', 'annot_A': {'boxes': {'maxX': 1690.041866, 'maxY': 1390.3275917, 'minX': 930.863466, 'minY': 398.9607617}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_B': {'boxes': {'maxX': 1690.763866, 'maxY': 1390.0645917, 'minX': 940.905466, 'minY': 398.6037617}, 'faceExp': '중립', 'bg': '도심 환경'}, 'annot_C': {'boxes': {'maxX': 1698.919866, 'maxY': 1390.3235917, 'minX': 939.869466, 'minY': 389.7727617}, 'faceExp': '중립', 'bg': '도심 환경'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '29b5343b8eca7460aea95cd18db40b015a58ec4db64b715d4771f63032e199c0_남_30_중립_숙박 및 거주공간_20210129192018-010-027.jpg', 'gender': '남', 'age': 30, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '숙박 및 거주공간', 'annot_A': {'boxes': {'maxX': 3404.7815, 'maxY': 1946.6035, 'minX': 2433.057, 'minY': 756.1026}, 'faceExp': '중립', 'bg': '상업시설/점포/시장'}, 'annot_B': {'boxes': {'maxX': 3444.36213889632, 'maxY': 1933.60286917294, 'minX': 2472.63763889632, 'minY': 815.305598318572}, 'faceExp': '중립', 'bg': '상업시설/점포/시장'}, 'annot_C': {'boxes': {'maxX': 3404.7815, 'maxY': 1946.6035, 'minX': 2433.057, 'minY': 756.1026}, 'faceExp': '중립', 'bg': '상업시설/점포/시장'}}
# ⚠️ file_name 없어서 건너뜀: {'filename': '4551a4c165093932b583c335b2c33abf357677f74c736c5e0ee8eb3b6c1306df_남_20_중립_교통&이동수단(엘리베이터 포함)_20210203064537-002-014.jpg', 'gender': '남', 'age': 20, 'isProf': '일반인', 'faceExp_uploader': '중립', 'bg_uploader': '교통/이동수단(엘리베이터 포함)', 'annot_A': {'boxes': {'maxX': 2557.5708, 'maxY': 1478.7566, 'minX': 1631.0908, 'minY': 267.00305}, 'faceExp': '중립', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_B': {'boxes': {'maxX': 2534.49518238477, 'maxY': 1439.0160142245, 'minX': 1654.16641761523, 'minY': 266.894450414054}, 'faceExp': '중립', 'bg': '교통/이동수단(엘리베이터 포함)'}, 'annot_C': {'boxes': {'maxX': 2539.9673946368, 'maxY': 1443.43444195202, 'minX': 1645.74302995633, 'minY': 266.917233355042}, 'faceExp': '중립', 'bg': '교통/이동수단(엘리베이터 포함)'}}
# 📌 전체 라벨 수: 0
# 📌 전체 이미지 수: 2161
#
# 📌 이미지 기본 정보 (샘플 5개):

# %%
import pandas as pd
import json

# 7가지 감정 파일 이름 목록
emotions = ['기쁨', '슬픔', '분노', '불안', '당황', '상처', '중립']
all_data = []

for emotion in emotions:
    file_path = f'{emotion}_sampled.json'
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # 각 JSON 파일의 데이터를 처리
    for item in data:
        filename = item['filename']
        uploader_info = {
            'gender': item['gender'],
            'age': item['age'],
            'isProf': item['isProf'],
            'faceExp_uploader': item['faceExp_uploader'],
            'bg_uploader': item['bg_uploader']
        }

        # 3명의 어노테이터 데이터 추출 및 리스트에 추가
        for annot_key in ['annot_A', 'annot_B', 'annot_C']:
            annot_data = item.get(annot_key, {}) # 데이터가 없는 경우를 대비
            if annot_data:
                annot_info = {
                    'filename': filename,
                    'annotator': annot_key,
                    'faceExp_annotator': annot_data.get('faceExp'),
                    'bg_annotator': annot_data.get('bg'),
                    'minX': annot_data.get('boxes', {}).get('minX'),
                    'minY': annot_data.get('boxes', {}).get('minY'),
                    'maxX': annot_data.get('boxes', {}).get('maxX'),
                    'maxY': annot_data.get('boxes', {}).get('maxY')
                }
                annot_info.update(uploader_info)
                all_data.append(annot_info)

# 통합된 데이터를 DataFrame으로 변환
df = pd.DataFrame(all_data)

print("통합된 데이터프레임의 상위 5개 행:")
print(df.head())
print("\n데이터프레임 정보:")
df.info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import pandas as pd
#       2 import json
#       4 # 7가지 감정 파일 이름 목록
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import json
import os
import glob
from PIL import Image

# ===== 경로 설정 =====
label_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent\labels"   # JSON들이 들어있는 폴더
image_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent"          # 이미지들이 들어있는 상위 폴더

# ===== 이미지 정보 함수 =====
def get_image_info(img_path):
    try:
        with Image.open(img_path) as img:
            width, height = img.size
            mode = img.mode
        file_size_kb = os.path.getsize(img_path) / 1024
        return width, height, mode, file_size_kb
    except:
        return None, None, None, None

# ===== 1. JSON 여러 개 읽기 =====
all_entries = []

for json_file in glob.glob(os.path.join(label_folder, "*.json")):
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    if isinstance(data, dict):
        for fname, info in data.items():
            all_entries.append({"file_name": fname, **info})
    elif isinstance(data, list):
        all_entries.extend(data)

print(f"📌 전체 라벨 수: {len(all_entries)}")

# ===== 2. 이미지 전체 경로 매핑 =====
image_paths = glob.glob(os.path.join(image_folder, "**", "*.jpg"), recursive=True)
image_paths += glob.glob(os.path.join(image_folder, "**", "*.png"), recursive=True)
image_map = {os.path.basename(p): p for p in image_paths}

print(f"📌 전체 이미지 수: {len(image_map)}")

# ===== 3. 샘플 5개 이미지 정보 출력 =====
print("\n📌 이미지 기본 정보 (샘플 5개):")
for entry in all_entries[:5]:
    img_name = os.path.basename(entry["file_name"])
    if img_name in image_map:
        img_path = image_map[img_name]
        w, h, mode, size_kb = get_image_info(img_path)
        print(f"{img_name} → {w}x{h}px, 모드:{mode}, 크기:{size_kb:.1f}KB, 라벨:{entry.get('emotion')}")
    else:
        print(f"{img_name} → ❌ 이미지 없음")
# Out:
# 📌 전체 라벨 수: 2210
# 📌 전체 이미지 수: 2161
#
# 📌 이미지 기본 정보 (샘플 5개):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 46
#      44 print("\n📌 이미지 기본 정보 (샘플 5개):")
#      45 for entry in all_entries[:5]:
# ---> 46     img_name = os.path.basename(entry["file_name"])
#      47     if img_name in image_map:
#      48         img_path = image_map[img_name]
#
# KeyError: 'file_name'

# %%
import json
import os
import glob
from PIL import Image

# ===== 경로 설정 =====
label_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent\labels"
image_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent"

# ===== 이미지 정보 함수 =====
def get_image_info(img_path):
    try:
        with Image.open(img_path) as img:
            width, height = img.size
            mode = img.mode
        file_size_kb = os.path.getsize(img_path) / 1024
        return width, height, mode, file_size_kb
    except:
        return None, None, None, None

# ===== 1. JSON 여러 개 읽기 =====
all_entries = []

for json_file in glob.glob(os.path.join(label_folder, "*.json")):
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    if isinstance(data, dict):
        for fname, info in data.items():
            entry = {"file_name": fname}
            if isinstance(info, dict):
                entry.update(info)
            all_entries.append(entry)

    elif isinstance(data, list):
        for item in data:
            # file_name 없으면 건너뛰기
            if "file_name" not in item and "filename" not in item:
                print(f"⚠️ file_name 또는 filename 없어서 건너뜀: {item}")
                continue

# file_name 키가 없고 filename이 있으면 filename을 file_name으로 바꿔줌
if "file_name" not in item and "filename" in item:
    item["file_name"] = item.pop("filename")

all_entries.append(item)

print(f"📌 전체 라벨 수: {len(all_entries)}")

# ===== 2. 이미지 전체 경로 매핑 =====
image_paths = glob.glob(os.path.join(image_folder, "**", "*.jpg"), recursive=True)
image_paths += glob.glob(os.path.join(image_folder, "**", "*.png"), recursive=True)
image_map = {os.path.basename(p): p for p in image_paths}

print(f"📌 전체 이미지 수: {len(image_map)}")

# ===== 3. 샘플 5개 이미지 정보 출력 =====
print("\n📌 이미지 기본 정보 (샘플 5개):")
count = 0
for entry in all_entries:
    if "file_name" not in entry:
        continue
    img_name = os.path.basename(entry["file_name"])
    if img_name in image_map:
        img_path = image_map[img_name]
        w, h, mode, size_kb = get_image_info(img_path)
        print(f"{img_name} → {w}x{h}px, 모드:{mode}, 크기:{size_kb:.1f}KB, 라벨:{entry.get('emotion')}")
    else:
        print(f"{img_name} → ❌ 이미지 없음")
    count += 1
    if count >= 5:
        break
# Out:
# 📌 전체 라벨 수: 1
# 📌 전체 이미지 수: 2161
#
# 📌 이미지 기본 정보 (샘플 5개):
# 4551a4c165093932b583c335b2c33abf357677f74c736c5e0ee8eb3b6c1306df_남_20_중립_교통&이동수단(엘리베이터 포함)_20210203064537-002-014.jpg → 3264x1836px, 모드:RGB, 크기:1172.0KB, 라벨:None

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.0 MB 11.7 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/11.0 MB 11.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 11.6 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 10.4 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-2.3.1 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from collections import Counter

# ====== 경로 설정 ======
json_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent\labels"
image_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent"

# ====== JSON 읽기 ======
all_entries = []
for fname in os.listdir(json_folder):
    if fname.lower().endswith(".json"):
        fpath = os.path.join(json_folder, fname)
        with open(fpath, "r", encoding="utf-8") as f:
            data = json.load(f)

        if isinstance(data, dict):
            for k, v in data.items():
                all_entries.append({
                    "file_name": k,
                    "emotion": v.get("emotion"),
                    "bbox": v.get("bbox")
                })
        elif isinstance(data, list):
            for item in data:
                all_entries.append({
                    "file_name": item.get("file_name"),
                    "emotion": item.get("emotion"),
                    "bbox": item.get("bbox")
                })

print(f"📌 총 라벨 수: {len(all_entries)}")

# ====== 이미지 폴더 읽기 ======
valid_exts = {".jpg", ".jpeg", ".png"}
image_files = []
for root, _, files in os.walk(image_folder):
    for file in files:
        if os.path.splitext(file)[1].lower() in valid_exts:
            image_files.append(file)

print(f"📌 총 이미지 수: {len(image_files)}")

# ====== 매칭 확인 ======
json_image_set = {os.path.basename(e["file_name"]) for e in all_entries if e["file_name"]}
folder_image_set = set(image_files)

only_in_json = json_image_set - folder_image_set
only_in_folder = folder_image_set - json_image_set
in_both = json_image_set & folder_image_set

print(f"✅ JSON에만 있는 이미지: {len(only_in_json)}")
print(f"✅ 폴더에만 있는 이미지: {len(only_in_folder)}")
print(f"✅ 둘 다 있는 이미지: {len(in_both)}")

# ====== 감정별 개수 ======
emotion_counts = Counter(e["emotion"] for e in all_entries if e["emotion"])
print("\n📊 감정별 이미지 개수:")
for emotion, cnt in emotion_counts.most_common():
    print(f"{emotion}: {cnt}")

# ====== bbox 개수 분포 ======
bbox_counts = []
for e in all_entries:
    if e["bbox"] is None:
        bbox_counts.append(0)
    elif isinstance(e["bbox"], list) and isinstance(e["bbox"][0], (int, float)):
        bbox_counts.append(1)  # 단일 bbox
    elif isinstance(e["bbox"], list):
        bbox_counts.append(len(e["bbox"]))  # bbox 여러 개
    else:
        bbox_counts.append(0)

bbox_count_dist = Counter(bbox_counts)
print("\n📦 bbox 개수 분포:")
for k, v in sorted(bbox_count_dist.items()):
    print(f"{k}개 bbox: {v}개 이미지")
# Out:
# 📌 총 라벨 수: 2210
# 📌 총 이미지 수: 2210
# ✅ JSON에만 있는 이미지: 0
# ✅ 폴더에만 있는 이미지: 2210
# ✅ 둘 다 있는 이미지: 0
#
# 📊 감정별 이미지 개수:
#
# 📦 bbox 개수 분포:
# 0개 bbox: 2210개 이미지

# %%
import os, glob, json
import unicodedata
from collections import Counter
from difflib import SequenceMatcher

# 경로 설정 (필요시 변경)
label_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent\labels"
image_folder = r"C:\Users\USER\Downloads\korean_emotion_complex_vision_1_percent"

def normalize_name(s):
    if not s:
        return ""
    s = str(s).strip()
    # 윈도우/URL 경로 제거
    s = s.replace("\\", "/")
    s = os.path.basename(s)
    # 정규화, 소문자화
    s = unicodedata.normalize("NFKC", s).lower()
    return s

# 1) JSON 파일들 로드 + 가능한 filename/emotion/bbox 키 탐색
all_entries = []
key_counter = Counter()
filename_key_counter = Counter()
emotion_key_counter = Counter()
bbox_key_counter = Counter()

json_files = sorted(glob.glob(os.path.join(label_folder, "*.json")))
print("🔎 JSON 파일 개수:", len(json_files))

for jf in json_files[:10]:  # 우선 최대 10개 json만 미리 로드해 구조 파악 (많으면 느릴 수 있음)
    with open(jf, "r", encoding="utf-8") as f:
        data = json.load(f)
    # 구조별로 sample 추출
    if isinstance(data, dict):
        # top-level이 dict인 경우: keys가 파일명일 수 있음
        for k, v in list(data.items())[:50]:  # 각 json에서 최대 50개만 샘플
            entry = {"_top_key": k, "_value_type": type(v).__name__}
            if isinstance(v, dict):
                entry.update(v)
                for kk in v.keys():
                    key_counter[kk]+=1
                # filename-like 키 탐색
                for fk in ("file_name","filename","file","image","img","image_id","name"):
                    if fk in v:
                        filename_key_counter[fk]+=1
                for ek in ("emotion","label","class","faceExp","faceExp_uploader","annot_faceExp"):
                    if ek in v:
                        emotion_key_counter[ek]+=1
                for bk in ("bbox","bboxes","boxes","annot","annotations","box"):
                    if bk in v:
                        bbox_key_counter[bk]+=1
            all_entries.append(entry)
    elif isinstance(data, list):
        for item in data[:200]:  # list이면 처음 200개만
            entry = {}
            if isinstance(item, dict):
                entry.update(item)
                for kk in item.keys():
                    key_counter[kk]+=1
                for fk in ("file_name","filename","file","image","img","image_id","name"):
                    if fk in item:
                        filename_key_counter[fk]+=1
                for ek in ("emotion","label","class","faceExp","faceExp_uploader"):
                    if ek in item:
                        emotion_key_counter[ek]+=1
                for bk in ("bbox","bboxes","boxes","annot","annotations","box"):
                    if bk in item:
                        bbox_key_counter[bk]+=1
            else:
                entry["_val"] = item
            all_entries.append(entry)
    else:
        # 다른 타입
        pass

print("\n📋 JSON 내부에서 관찰된 필드(상위 몇개):")
for k,c in key_counter.most_common(30):
    print(f"  {k}: {c}")

print("\n🔑 filename-like 키 빈도:")
for k,c in filename_key_counter.most_common():
    print(f"  {k}: {c}")

print("\n😊 emotion-like 키 빈도:")
for k,c in emotion_key_counter.most_common():
    print(f"  {k}: {c}")

print("\n📦 bbox-like 키 빈도:")
for k,c in bbox_key_counter.most_common():
    print(f"  {k}: {c}")

# 2) all_entries에서 실제로 파일명(가능한 후보) 리스트 추출 (여러 키 후보 체크)
json_name_candidates = []
for e in all_entries:
    # 우선 많이 쓰이는 키들 순서대로 대입
    name = None
    for fk in ("file_name","filename","file","image","img","image_id","name","_top_key"):
        if fk in e and e[fk]:
            name = e[fk]
            break
    if name:
        json_name_candidates.append(name)

json_name_candidates = [str(x) for x in json_name_candidates]
print("\n샘플 JSON에서 추출한 파일명 후보 (최대 20):")
for s in json_name_candidates[:20]:
    print("  ", repr(s)[:200])

print("\n총 JSON에서 수집된 filename 후보 개수:", len(json_name_candidates))

# 3) 폴더에서 이미지 파일 리스트 수집 (하위폴더 포함)
valid_exts = {".jpg",".jpeg",".png",".bmp",".webp"}
image_paths = []
for root,_,files in os.walk(image_folder):
    for f in files:
        if os.path.splitext(f)[1].lower() in valid_exts:
            image_paths.append(os.path.join(root,f))
image_basenames = [os.path.basename(p) for p in image_paths]

print("🔎 폴더에서 찾은 전체 이미지 개수:", len(image_paths))
print("샘플 이미지 파일명 (최대 20):")
for p in image_basenames[:20]:
    print("  ", p)

# 4) 정규화(소문자+basename) 후 교집합 검사
json_norm = [normalize_name(x) for x in json_name_candidates if x]
img_norm = [normalize_name(x) for x in image_basenames if x]

set_json = set(json_norm)
set_img = set(img_norm)

print("\n교집합 검사:")
print("  JSON 고유 이름 개수:", len(set_json))
print("  IMAGE 고유 이름 개수:", len(set_img))
print("  교집합 개수:", len(set_json & set_img))

# 5) 만약 교집합 0이면 추가 진단: 확장자 제거, 접두사 매칭, prefix 토큰 매칭
intersection = set_json & set_img
if len(intersection) == 0:
    print("\n>>> 교집합이 0입니다. 추가 진단을 수행합니다.")
    # 확장자 제거 비교
    json_noext = {os.path.splitext(n)[0] for n in json_norm}
    img_noext = {os.path.splitext(n)[0] for n in img_norm}
    print("  (확장자 제거) 교집합 개수:", len(json_noext & img_noext))

    # 접두어(언더스코어 앞) 매칭
    def prefix(s): return s.split("_")[0] if s else ""
    json_prefixes = {prefix(n) for n in json_norm}
    img_prefixes = {prefix(n) for n in img_norm}
    common_prefixes = json_prefixes & img_prefixes
    print("  (prefix before '_') JSON prefix 개수:", len(json_prefixes))
    print("  (prefix before '_') IMG prefix 개수:", len(img_prefixes))
    print("  (prefix) 교집합 개수:", len(common_prefixes))

    # 가장 많이 겹치는 prefix 10개 출력
    print("\n  공통 prefix 샘플(최대 20):")
    for p in list(common_prefixes)[:20]:
        print("   ", p)

    # 유사도 기반 매칭 (처음 30개의 JSON에 대해 가장 가까운 이미지 찾음)
    print("\n  유사도(SequenceMatcher)로 고급 매칭 시도(첫 30개 JSON 대상):")
    for j in json_norm[:30]:
        best_score = 0
        best_img = None
        for im in img_norm:
            score = SequenceMatcher(None, j, im).ratio()
            if score > best_score:
                best_score = score
                best_img = im
        if best_score > 0.9:
            print("    가능 매칭:", j, "->", best_img, f"(score={best_score:.3f})")
        # if no good match, print a short info for first few
        elif len([x for x in img_norm if x.startswith(j.split("_")[0])])>0:
            # there are images starting with same token
            pass
        else:
            # print a few non-matching json names for inspection
            if json_norm.index(j) < 10:
                print("    미매칭 샘플:", j)

# 6) unmatched 샘플 출력 (json에 있지만 폴더에 없는 샘플 몇개)
unmatched = [n for n in json_norm if n not in set_img]
print("\n미매칭 JSON 샘플 (최대 20):")
for n in unmatched[:20]:
    print("  ", n)

print("\n진단 완료 — 위 출력 결과를 붙여 주세요. (특히: JSON에서 추출한 파일명 후보 샘플 / filename-like 키 빈도 / prefix 교집합 개수 / 유사도 매칭 결과)")
# Out:
# 🔎 JSON 파일 개수: 7
#
# 📋 JSON 내부에서 관찰된 필드(상위 몇개):
#   filename: 1400
#   gender: 1400
#   age: 1400
#   isProf: 1400
#   faceExp_uploader: 1400
#   bg_uploader: 1400
#   annot_A: 1400
#   annot_B: 1400
#   annot_C: 1400
#
# 🔑 filename-like 키 빈도:
#   filename: 1400
#
# 😊 emotion-like 키 빈도:
#   faceExp_uploader: 1400
#
# 📦 bbox-like 키 빈도:
#
# 샘플 JSON에서 추출한 파일명 후보 (최대 20):
#    '5a30dc193e2c6144184968043c00773270b111a23a3c83b00f3971c9cc8a670d_남_30_기쁨_도심 환경_20201205004857-008-002.jpg'
#    '0d18ae1ed7d9e912864b736523a94a24db0595bf273964cb532e62a6087cf325_여_30_기쁨_행사&사무공간_20201207000342-006-001.jpg'
#    '8f7e2f5214659c45cdcbc99a4e9ec29cf0b7571844a28e5f0de93af85aa7d76a_여_20_기쁨_문화재 및 유적지_20210129175103-009-002.jpg'
#    '2964f04ec5e9bcc45276def3a6e08a3c2d1418995cf31f31d7fb9c147784c08a_남_50_기쁨_공공시설&종교&의료시설_20210125171959-001-013.jpg'
#    '5feb258aabe4308f740ab36c133ef854074b138dcad3d6c66e519820dd2ec9b9_남_20_기쁨_스포츠 관람 및 레저시설_20210119120442-004-001.jpg'
#    '6c95a9432ec1dc577c3d2041ead6a86d920ab836420f02ab3981b4b1f73a6d35_남_20_기쁨_상업시설&점포&시장_20201207162128-003-021.jpg'
#    '6a44de2e514d08e712dffc46e8133298af75b80668546e781bcee97fa777ca0e_남_20_기쁨_상업시설&점포&시장_20201205170307-003-009.jpg'
#    '26fb7dc0cd75beefc6b3c22583094b9441833566d0e30079d8dcea266a281950_남_20_기쁨_숙박 및 거주공간_20210204211729-010-007.jpg'
#    '559fa2f1d759bf4567906aba12d64a29b730535f6ea0a0e3d52d5baf025d7728_여_30_기쁨_교통&이동수단(엘리베이터 포함)_20201206005320-002-002.jpg'
#    '1eab9325767c0fdbe195bcd9da5542f92609fcc1ebbb52953be96718dc57d82a_여_30_기쁨_오락&공연시설_20201206221022-005-004.jpg'
#    '36f3d025faf2e87a1c5e83c4b5c36964d2c80fb29a1d29739cb5ad1656386f99_남_20_기쁨_실외 자연환경_20210121103252-007-002.jpg'
#    '821a4cf4393217eb1e67aa65c0daa2347025405a001df78d3caf90ea759adfab_여_30_기쁨_실외 자연환경_20210122144349-007-002.jpg'
#    '5f2ac0f161ab6f0b07a219002d00c27397b1f15f0d470339aa0c8cf95eced4b0_남_20_기쁨_숙박 및 거주공간_20210119121700-010-008.jpg'
#    '52e9bd799abddc270c5447644821c8fa11fc65cc1cdcaea54b24bc13ca69577c_여_30_기쁨_교통&이동수단(엘리베이터 포함)_20201201132438-002-003.jpg'
#    '2e9ee57fed0d4333cb8cff62cab4b9dc05e90a73e108fa16ac0910e5c9de1d3d_여_20_기쁨_실외 자연환경_20210121172929-007-012.jpg'
#    '75c554e12ca755112a797b612dc18fdff8fc1fb8c2c1dd636f6b312fa4768b10_여_30_기쁨_실외 자연환경_20201204220354-007-009.jpg'
#    '37a29bebaec2766329afbc04710e11ad7e47d5ea110a384574efd2f3f6a039fb_남_30_기쁨_행사&사무공간_20201205003024-006-003.jpg'
#    '30ec2f1933c9645a6c418555299f14fb1d85f175d4a2ab87006652c07d7433f6_여_30_기쁨_숙박 및 거주공간_20210119203857-010-011.jpg'
#    '01a6c69e76d729863380b8391d780e53070cf8629ad9ffd5d06826551271fe74_남_30_기쁨_숙박 및 거주공간_20201207110157-010-006.jpg'
#    '5a492f03b2d2b9401419999b80224fee64f211976fb3d82fd1ce32efab97a82c_여_30_기쁨_숙박 및 거주공간_20210210114352-010-005.jpg'
#
# 총 JSON에서 수집된 filename 후보 개수: 1400
# 🔎 폴더에서 찾은 전체 이미지 개수: 2210
# 샘플 이미지 파일명 (최대 20):
#    007f299267a9d6a145f627e9993aeae4e8323652785a2f4d1b896f6489d3acc0_남_30_기쁨_교통&이동수단(엘리베이터 포함)_20201202210239-002-010.jpg
#    01a6c69e76d729863380b8391d780e53070cf8629ad9ffd5d06826551271fe74_남_30_기쁨_문화재 및 유적지_20201207110149-009-024.jpg
#    01a6c69e76d729863380b8391d780e53070cf8629ad9ffd5d06826551271fe74_남_30_기쁨_숙박 및 거주공간_20201207110157-010-006.jpg
#    033de467a2d107ce2004c41451b69ba93196a4e1fe423f59a7abad9050a2d193_남_40_기쁨_공공시설&종교&의료시설_20210118154103-001-021.jpg
#    03f84d01e35a8d2beed4c9467a82c212daa05809d0bc980865765fe6b0f2e9cd_남_20_기쁨_도심 환경_20210201170908-008-015.jpg
#    054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_남_30_기쁨_공공시설&종교&의료시설_20201206184316-001-014.jpg
#    054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_남_30_기쁨_상업시설&점포&시장_20201206184354-003-004.jpg
#    054b1e76bacf338595bd6718f1f208ff2d2bbc5a4803d3213dfd580976dacfcf_남_30_기쁨_실외 자연환경_20201206184439-007-009.jpg
#    06e5f8f8123ee831d958c5c7b99f48f08251d756922cda519d746f6c3c7bb4ed_남_30_기쁨_상업시설&점포&시장_20210126013233-003-016.jpg
#    06e5f8f8123ee831d958c5c7b99f48f08251d756922cda519d746f6c3c7bb4ed_남_30_기쁨_숙박 및 거주공간_20210126013604-010-009.jpg
#    08a32c1632b7dff63981271350669d8b39d567a5db78dadeb36a0aae4323aa2f_남_20_기쁨_상업시설&점포&시장_20201207131431-003-011.jpg
#    08a32c1632b7dff63981271350669d8b39d567a5db78dadeb36a0aae4323aa2f_남_20_기쁨_실외 자연환경_20201207131509-007-004.jpg
#    08b5bc40590b701dc2b457c5a47046b53cfa54907762198785497df976084785_여_20_기쁨_상업시설&점포&시장_20210127162750-003-015.jpg
#    08c0d9389dbc222023035a3ef6ad78ff04b107aa756b0c228f2455ead387942e_여_20_기쁨_도심 환경_20210208201641-008-002.jpg
#    090f71a0a0cd220466761f8baefa97a4430089f47b11198d8064e72b11216585_남_30_기쁨_실외 자연환경_20201207142609-007-013.jpg
#    0a3a21be68414f07a0e035671e8e3911c7376b4cfc6e100c8a1e240423676188_남_20_기쁨_공공시설&종교&의료시설_20201206192953-001-001.jpg
#    0a3a21be68414f07a0e035671e8e3911c7376b4cfc6e100c8a1e240423676188_남_20_기쁨_도심 환경_20201206193143-008-012.jpg
#    0a88a23fd9e2225216ed0ab0e2c1d01801be2e23b1f916fcab139fccd47811d2_남_20_기쁨_실외 자연환경_20210125160732-007-005.jpg
#    0b1d79067bd95d04cd88f5792741b964077adc98ec7f59cd480d4901f5f6eed8_남_50_기쁨_공공시설&종교&의료시설_20210209142931-001-017.jpg
#    0b33836b914f544c31e3a642ccccbb94114040537440b4df3b9250d025fc39a5_여_20_기쁨_숙박 및 거주공간_20210209150051-010-024.jpg
#
# 교집합 검사:
#   JSON 고유 이름 개수: 1400
#   IMAGE 고유 이름 개수: 2210
#   교집합 개수: 1400
#
# 미매칭 JSON 샘플 (최대 20):
#
# 진단 완료 — 위 출력 결과를 붙여 주세요. (특히: JSON에서 추출한 파일명 후보 샘플 / filename-like 키 빈도 / prefix 교집합 개수 / 유사도 매칭 결과)

# %%
import os
import json
import pandas as pd

# 경로 설정
json_dir = "./json_folder"       # JSON 파일들이 들어있는 폴더
img_dir = "./image_folder"       # 이미지들이 들어있는 폴더

# 1. JSON에서 파일명 수집
json_filenames = set()
for file in os.listdir(json_dir):
    if file.endswith(".json"):
        with open(os.path.join(json_dir, file), encoding="utf-8") as f:
            data = json.load(f)
            for item in data:
                if "filename" in item:  # JSON 키 확인
                    json_filenames.add(item["filename"])

# 2. 폴더의 이미지 파일명 수집
img_filenames = set(os.listdir(img_dir))

# 3. 폴더에만 있는 파일 찾기
only_in_folder = sorted(list(img_filenames - json_filenames))

print(f"폴더에만 있는 이미지 수: {len(only_in_folder)}")
print("샘플 10개:", only_in_folder[:10])

# 4. CSV로 저장
df_only = pd.DataFrame({"filename": only_in_folder})
df_only.to_csv("only_in_folder.csv", index=False, encoding="utf-8-sig")
print("📄 only_in_folder.csv 저장 완료")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 3
#       1 import os
#       2 import json
# ----> 3 import pandas as pd
#       5 # 경로 설정
#       6 json_dir = "./json_folder"       # JSON 파일들이 들어있는 폴더
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# c:\ex\anaconda\envs\djangoWeb\python.exe

# %%
# !{sys.executable} -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python313\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python313\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\ex\anaconda\envs\djangoweb\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
